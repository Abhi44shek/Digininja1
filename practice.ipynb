# %%
from pytrends.request import TrendReq

# %%
pytrends = TrendReq()
kw_list = ['Pizza']
pytrends.build_payload(kw_list,  timeframe='today 5-y')
pytrends.interest_over_time()
# Out:
#             Pizza  isPartial
# date
# 2017-05-21     76      False
# 2017-05-28     79      False
# 2017-06-04     79      False
# 2017-06-11     81      False
# 2017-06-18     82      False
# ...           ...        ...
# 2022-04-17     78      False
# 2022-04-24     74      False
# 2022-05-01     77      False
# 2022-05-08     74      False
# 2022-05-15     69       True
#
# [261 rows x 2 columns]

# %%
import pandas as pd                        
from pytrends.request import TrendReq
pytrend = TrendReq()

#provide your search terms
kw_list=['Facebook', 'Apple', 'Amazon', 'Netflix', 'Google']

#search interest per region
#run model for keywords (can also be competitors)
pytrend.build_payload(kw_list, timeframe='today 1-m')

# Interest by Region
regiondf = pytrend.interest_by_region()
#looking at rows where all values are not equal to 0
regiondf = regiondf[(regiondf != 0).all(1)]

#drop all rows that have null values in all columns
regiondf.dropna(how='all',axis=0, inplace=True)

#visualise
regiondf.plot(figsize=(20, 12), y=kw_list, kind ='bar')
# Out:
# <AxesSubplot:xlabel='geoName'>

# %%
import tweepy

# Authenticate to Twitter
auth = tweepy.OAuthHandler("U8xbVoaodJdFq2UML83iGRsCl","YNQlKjTYhI5iogc6O9cfv2k1FN58UeFxRMWLOQZluBmClc7Bf9")
auth.set_access_token("1522890216217972739-rNhURPiBSIuOkJD16LdN50viiObzbJ", "0sxdJxkb20mNSZIN8Q6Zu2tM3Rbmic26gDPKd7BsIBrDY")

# Create API object
api = tweepy.API(auth)

# Create a tweet
api.update_status("Hello Tweepy")
# Out:
# ---------------------------------------------------------------------------
# Unauthorized                              Traceback (most recent call last)
# g:\django_2022\Digininja\practice.ipynb Cell 2' in <cell line: 11>()
#       <a href='vscode-notebook-cell:/g%3A/django_2022/Digininja/practice.ipynb#ch0000001?line=7'>8</a> api = tweepy.API(auth)
#      <a href='vscode-notebook-cell:/g%3A/django_2022/Digininja/practice.ipynb#ch0000001?line=9'>10</a> # Create a tweet
# ---> <a href='vscode-notebook-cell:/g%3A/django_2022/Digininja/practice.ipynb#ch0000001?line=10'>11</a> api.update_status("Hello Tweepy")
#
# File c:\Users\abhishek dwivedi\miniconda3\lib\site-packages\tweepy\api.py:46, in payload.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      <a href='file:///c%3A/Users/abhishek%20dwivedi/miniconda3/lib/site-packages/tweepy/api.py?line=43'>44</a> kwargs['payload_list'] = payload_list
# ...
